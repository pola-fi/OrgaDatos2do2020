# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt

#Levantamos el archivo que ya tiene los datos principales depurados
df = pd.read_csv("./data/train_clean.csv")

#Creo 2 columnas para saber si se obtuvo Closed Won o Closed Lost según si vale 1 o 0
df['Closed_Lost'] = 0
df['Closed_Won'] = 0

df.loc[df['Stage'] == 'Closed Lost', 'Closed_Lost'] = 1
df.loc[df['Stage'] == 'Closed Won', 'Closed_Won'] = 1
df.loc[df['Stage'] == 'Closed Won', 'TRF_sold'] = df['TRF']
df['Total_oportunities'] = df['Closed_Won'] + df['Closed_Lost']
df_filtered.head(50)
df_filtered = df.groupby('Region').sum()
df_filtered.head(50)
# df_filtered['Probability_to_closed_won'] = df_filtered['Closed_Won'] / (df_filtered['Closed_Won'] + df_filtered['Closed_Lost'])
# df_filtered = df_filtered.loc[df_filtered['Total_oportunities'] > 50]
# df_filtered.sort_values(by='Probability_to_closed_won', ascending=False, inplace=True)
# df_filtered.head(50)
# Out:
#                     ID  Pricing, Delivery_Terms_Quote_Appr  \
# Region
# APAC          46765903                                2285
# Americas      68361361                                2939
# EMEA          70893216                                3556
# Japan        110706864                                4679
# Middle East    1926822                                 170
#
#              Pricing, Delivery_Terms_Approved  Bureaucratic_Code_0_Approval  \
# Region
# APAC                                     1654                          2072
# Americas                                 2026                          2210
# EMEA                                     2693                          2330
# Japan                                    3333                          1215
# Middle East                               141                           167
#
#              Bureaucratic_Code_0_Approved  Opportunity_ID          ASP  \
# Region
# APAC                                 1446        18123718   1289.02795
# Americas                             1346        23068100   1589.44492
# EMEA                                 1710        25282141   1823.80993
# Japan                                 725        22350385  90682.64600
# Middle East                           134          943613     60.39450
#
#              ASP_(converted)  Delivery_Year    TRF  Total_Amount  \
# Region
# APAC              1200.99694        6558237  10711  3.986059e+09
# Americas          1589.44492        7934063  16252  7.455905e+09
# EMEA              2054.43629        9400298  10796  4.311561e+09
# Japan             1016.87510        9819643    852  1.397474e+10
# Middle East         60.44300         342959    825  2.947246e+08
#
#              Total_Taxable_Amount  Closed_Lost  Closed_Won  TRF_sold  \
# Region
# APAC                 7.731745e+09         1355        1896     327.0
# Americas             1.609553e+10         2140        1793    1439.0
# EMEA                 7.089502e+09         2189        2471    1076.0
# Japan                2.097463e+10         1546        3323     173.0
# Middle East          3.755538e+08          120          50       8.0
#
#              Total_oportunities
# Region
# APAC                       3251
# Americas                   3933
# EMEA                       4660
# Japan                      4869
# Middle East                 170
